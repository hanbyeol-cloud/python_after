# %%
import pyaudio

audio = pyaudio.PyAudio()

for index in range(audio.get_device_count()):
    desc = audio.get_device_info_by_index(index)
    print("DEVICE: {device}, INDEX: {index}, RATE: {rate} ".format(
        device=desc["name"], index=index, rate=int(desc["defaultSampleRate"])))
# Out:
# DEVICE: Microsoft Sound Mapper - Input, INDEX: 0, RATE: 44100
# DEVICE: 마이크(Realtek High Definition Aud, INDEX: 1, RATE: 44100
# DEVICE: 스테레오 믹스(Realtek High Definition, INDEX: 2, RATE: 44100
# DEVICE: Microsoft Sound Mapper - Output, INDEX: 3, RATE: 44100
# DEVICE: 스피커(Realtek High Definition Aud, INDEX: 4, RATE: 44100
# DEVICE: Speakers (Realtek HD Audio output), INDEX: 5, RATE: 44100
# DEVICE: 마이크 (Realtek HD Audio Mic input), INDEX: 6, RATE: 44100
# DEVICE: 라인 입력 (Realtek HD Audio Line input), INDEX: 7, RATE: 44100
# DEVICE: 스테레오 믹스 (Realtek HD Audio Stereo input), INDEX: 8, RATE: 48000

# %%
audio.get_device_count()
# Out:
# 9

# %%
import pyaudio
import wave

CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100
RECORD_SECONDS = 20
WAVE_OUTPUT_FILENAME = "output.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK,
               input_device_index=2)

print("Start to record the audio.")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("Recording is finished.")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open("music/"+WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# Start to record the audio.
# Recording is finished.

# %%
import pyaudio
import wave
import sys

CHUNK = 1024

if len(sys.argv) < 2:
    print("Plays a wave file.\n\nUsage: %s filename.wav" % sys.argv[0])
    sys.exit(-1)

# %%
wf = wave.open("./music/0045. 괜찮아 사랑이야.wav", 'rb')

# %%
p = pyaudio.PyAudio()

stream = p.open(format=p.get_format_from_width(wf.getsampwidth()),
                channels=wf.getnchannels(),
                rate=wf.getframerate(),
                output=True)

data = wf.readframes(CHUNK)
data
# Out:
# b'
# ...

# %%
while data != '':
    stream.write(data)
    data = wf.readframes(CHUNK)

stream.stop_stream()
stream.close()

p.terminate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-b4828c5ce459> in <module>
#       1 while data != '':
# ----> 2     stream.write(data)
#       3     data = wf.readframes(CHUNK)
#       4
#       5 stream.stop_stream()
#
# ~\anaconda3\lib\site-packages\pyaudio.py in write(self, frames, num_frames, exception_on_underflow)
#     583             #print len(frames), self._channels, self._width, num_frames
#     584
# --> 585         pa.write_stream(self._stream, frames, num_frames,
#     586                         exception_on_underflow)
#     587
#
# KeyboardInterrupt:

# %%
https://jonhyuk0922.tistory.com/m/114
https://m.blog.naver.com/sun32ys/221644565042
