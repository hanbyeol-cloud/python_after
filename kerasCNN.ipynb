# %% [markdown]
# ### Module Import

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

import numpy as np

# %% [markdown]
# ### Load Data and Processing

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

print(x_train_full.shape, y_train_full.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 29s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print(y_test)
# Out:
# [[3]
#  [8]
#  [8]
#  ...
#  [5]
#  [1]
#  [7]]

# %%
np.random.seed(1630)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'sheep', 'truck']

sample_size = 9
random_idx = np.random.randint(60000, size=sample_size)

plt.figure(figsize=(5, 5))
for i, idx in enumerate(random_idx):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_full[i])
    plt.xlabel(class_names[int(y_train_full[i])])

plt.show()

# %%
x_mean = np.mean(x_train_full, axis=(0, 1, 2))
x_std = np.std(x_train_full, axis=(0, 1, 2))

x_train_full = (x_train_full - x_mean) / x_std
x_test = (x_test - x_mean) / x_std

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size=0.3)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_val.shape)
print(y_val.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (35000, 32, 32, 3)
# (35000, 1)
# (15000, 32, 32, 3)
# (15000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### Build Model and Compile

# %%
def model_build():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)

  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)

  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)

  output = Flatten()(output)
  output = Dense(256, activation='relu')(output)
  output = Dense(128, activation='relu')(output)
  output = Dense(10, activation='softmax')(output)

  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=1e-4),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 651,978
# Trainable params: 651,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train and Evaluate Model

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 36s 20ms/step - loss: 2.0690 - accuracy: 0.2484 - val_loss: 1.6156 - val_accuracy: 0.4261
# Epoch 2/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.5411 - accuracy: 0.4542 - val_loss: 1.4355 - val_accuracy: 0.4923
# Epoch 3/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.4040 - accuracy: 0.5002 - val_loss: 1.3375 - val_accuracy: 0.5252
# Epoch 4/30
# 137/137 [==============================] - 2s 13ms/step - loss: 1.3078 - accuracy: 0.5380 - val_loss: 1.2938 - val_accuracy: 0.5455
# Epoch 5/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.2454 - accuracy: 0.5606 - val_loss: 1.2280 - val_accuracy: 0.5685
# Epoch 6/30
30
# 137/137 [==============================] - 2s 14ms/step - loss: 0.6465 - accuracy: 0.7812 - val_loss: 0.9219 - val_accuracy: 0.6884
# Epoch 30/30
# 137/137 [==============================] - 2s 14ms/step - loss: 0.6282 - accuracy: 0.7883 - val_loss: 0.9078 - val_accuracy: 0.6937

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()

# %%
def model_build2():
  model = Sequential()

  input = Input(shape=(32, 32, 3))

  output = Conv2D(filters=32, kernel_size=3, padding='same', activation='relu')(input)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(input)

  output = Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  output = Dropout(0.5)(output)

  output = Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)

  output = Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(output)
  output = BatchNormalization()(output)
  output = MaxPool2D(pool_size=(2, 2), strides=2, padding='same')(output)
  output = Dropout(0.5)(output)

  output = Flatten()(output)
  output = Dense(512, activation='relu')(output)
  output = Dropout(0.5)(output)
  output = Dense(256, activation='relu')(output)
  output = Dropout(0.5)(output)
  output = Dense(10, activation='softmax')(output)

  model = Model(inputs=[input], outputs=output)

  model.compile(optimizer=Adam(learning_rate=0.001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  
  return model

# %%
model = model_build2()
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 3)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 64)        1792
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,031,306
# Trainable params: 1,030,410
# Non-trainable params: 896
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                    epochs=30,
                    batch_size=256,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/30
# 137/137 [==============================] - 2s 14ms/step - loss: 2.6685 - accuracy: 0.1891 - val_loss: 4.1037 - val_accuracy: 0.1007
# Epoch 2/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.7821 - accuracy: 0.3345 - val_loss: 5.0955 - val_accuracy: 0.1355
# Epoch 3/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.6424 - accuracy: 0.3953 - val_loss: 2.9553 - val_accuracy: 0.2251
# Epoch 4/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.5267 - accuracy: 0.4401 - val_loss: 1.8334 - val_accuracy: 0.3912
# Epoch 5/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.4474 - accuracy: 0.4761 - val_loss: 1.4813 - val_accuracy: 0.4906
# Epoch 6/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.3759 - accuracy: 0.5041 - val_loss: 1.3124 - val_accuracy: 0.5215
# Epoch 7/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.3198 - accuracy: 0.5330 - val_loss: 1.2233 - val_accuracy: 0.5622
# Epoch 8/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.2798 - accuracy: 0.5455 - val_loss: 1.2195 - val_accuracy: 0.5637
# Epoch 9/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.2281 - accuracy: 0.5666 - val_loss: 1.1067 - val_accuracy: 0.6136
# Epoch 10/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1866 - accuracy: 0.5835 - val_loss: 1.1481 - val_accuracy: 0.5915
# Epoch 11/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1588 - accuracy: 0.5913 - val_loss: 1.1613 - val_accuracy: 0.5965
# Epoch 12/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1324 - accuracy: 0.6007 - val_loss: 1.0654 - val_accuracy: 0.6163
# Epoch 13/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0993 - accuracy: 0.6112 - val_loss: 1.0226 - val_accuracy: 0.6381
# Epoch 14/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0853 - accuracy: 0.6188 - val_loss: 1.0268 - val_accuracy: 0.6346
# Epoch 15/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0433 - accuracy: 0.6286 - val_loss: 0.9745 - val_accuracy: 0.6610
# Epoch 16/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0339 - accuracy: 0.6424 - val_loss: 0.9751 - val_accuracy: 0.6637
# Epoch 17/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0009 - accuracy: 0.6478 - val_loss: 0.9662 - val_accuracy: 0.6651
# Epoch 18/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9936 - accuracy: 0.6556 - val_loss: 0.9847 - val_accuracy: 0.6567
# Epoch 19/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9687 - accuracy: 0.6625 - val_loss: 0.9140 - val_accuracy: 0.6815
# Epoch 20/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9513 - accuracy: 0.6623 - val_loss: 0.9356 - val_accuracy: 0.6741
# Epoch 21/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9429 - accuracy: 0.6767 - val_loss: 0.9053 - val_accuracy: 0.6863
# Epoch 22/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9277 - accuracy: 0.6795 - val_loss: 0.9440 - val_accuracy: 0.6771
# Epoch 23/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9108 - accuracy: 0.6824 - val_loss: 0.9089 - val_accuracy: 0.6899
# Epoch 24/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8902 - accuracy: 0.6929 - val_loss: 0.9014 - val_accuracy: 0.6889
# Epoch 25/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8826 - accuracy: 0.6949 - val_loss: 0.8816 - val_accuracy: 0.6983
# Epoch 26/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8656 - accuracy: 0.6993 - val_loss: 0.8874 - val_accuracy: 0.6951
# Epoch 27/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8559 - accuracy: 0.7007 - val_loss: 0.8693 - val_accuracy: 0.7016
# Epoch 28/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8394 - accuracy: 0.7058 - val_loss: 0.9217 - val_accuracy: 0.6842
# Epoch 29/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8253 - accuracy: 0.7122 - val_loss: 0.8422 - val_accuracy: 0.7104
# Epoch 30/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8082 - accuracy: 0.7215 - val_loss: 0.8434 - val_accuracy: 0.7064

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b--', label='loss')
plt.plot(history.history['val_loss'], 'r:', label='val loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'b--', label='accuracy')
plt.plot(history.history['val_accuracy'], 'r:', label='val accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()

plt.show()
